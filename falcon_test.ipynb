# %%
# !pip install pqcrypto
# Out:
# Requirement already satisfied: pqcrypto in /opt/anaconda3/lib/python3.13/site-packages (0.3.4)
# Requirement already satisfied: cffi>=1.17.1 in /opt/anaconda3/lib/python3.13/site-packages (from pqcrypto) (1.17.1)
# Requirement already satisfied: pycparser in /opt/anaconda3/lib/python3.13/site-packages (from cffi>=1.17.1->pqcrypto) (2.21)

# %%
# !ls /opt/anaconda3/lib/python3.13/site-packages/pqcrypto/sign/
# Out:
# __init__.py                  sphincs_sha2_192f_simple.py
# __pycache__                  sphincs_sha2_192s_simple.py
# falcon_1024.py               sphincs_sha2_256f_simple.py
# falcon_512.py                sphincs_sha2_256s_simple.py
# falcon_padded_1024.py        sphincs_shake_128f_simple.py
# falcon_padded_512.py         sphincs_shake_128s_simple.py
# ml_dsa_44.py                 sphincs_shake_192f_simple.py
# ml_dsa_65.py                 sphincs_shake_192s_simple.py
# ml_dsa_87.py                 sphincs_shake_256f_simple.py
# sphincs_sha2_128f_simple.py  sphincs_shake_256s_simple.py
# sphincs_sha2_128s_simple.py

# %%
import pqcrypto.sign
# This will list all signature modules you can actually import
print([name for name in dir(pqcrypto.sign) if 'falcon' in name])
# Out:
# ['falcon_1024']

# %%
import base64

# The common naming in recent pqcrypto builds is falcon_1024
from pqcrypto.sign import falcon_1024

# 1. Generate Keypair
public_key, secret_key = falcon_1024.generate_keypair()

print(f"--- FN-DSA / Falcon-1024 (FIPS 207) ---")
print(f"Public Key Size: {len(public_key)} bytes")
print(f"Secret Key Size: {len(secret_key)} bytes\n")

# 2. Sign a Message
message = b"fear not, for I am with you; be not dismayed, for I am your God; I will strengthen you, I will help you, I will uphold you with my righteous right hand."
print(f"Message to be signed: {message}\n")

signature = falcon_1024.sign(secret_key, message)

print(f"Signature: {signature}\n")
print(f"Signature in hex: {signature.hex()}\n")
print(f"Signature in base64: {base64.b64encode(signature).decode('utf-8')}\n")
print(f"\nSignature Size: {len(signature)} bytes\n")

# 3. Verify
try:
    # Note: pqcrypto verify returns None on success or raises an error
    falcon_1024.verify(public_key, message, signature)
    print("✅ Success! Signature is valid and authentic.")
except Exception as e:
    print(f"❌ Verification Failed: {e}")
# Out:
# --- FN-DSA / Falcon-1024 (FIPS 207) ---
# Public Key Size: 1793 bytes
# Secret Key Size: 2305 bytes
#
# Message to be signed: b'fear not, for I am with you; be not dismayed, for I am your God; I will strengthen you, I will help you, I will uphold you with my righteous right hand.'
#
# Signature: b':\x15\xacu*\x9e\x02=a\x98\x94\xeds,7\xd5\x8a\x87}\xbf\rr\xab\xd5\x0b\xe0\xb4s\x91\x0be^\xb3/\nfx)\xa5\xe2\xc6[\xe45N\xde}\xb5Y\x8e\x8f)C`\xd8\xe3D\xbaD4\x1d\xfd\xaaw2\x9c4g\xc6&\xa6D\xd2\x88\xa6\xadR\xb4\x10\xd9\x02?\x07`\xdb9-9t\xaa7\xa8\x92\n\xb2]\xd2?\x0f\x03\xe0\xef\x17u?.i\x93[\xd8\xc5\xb9\xaes<b%B\xce\xce*\xaf<\xe9\x83\xc5Eb\xd4\x9b\xa7*Zb\x082X\x98\xe4\xd2\xda\x9bB\xfc\xb1\x08\x99\x8f\x14\xab\x86\x9fs\xf8\xe8\xf0\'\r\xa2\xf56P\xa0\xf1W\'K\\\xa7\xcf\xa8\xbf\x92\xeet\xd3J\x0e{\x8c\xd3\x1f\'\xee\xcb9bQ\xc3\xd8\xb4\xd4\xb1\xf9\x04\xca>\xba\xec\xafz\n\xef\\\x90\xe6\xc6\xd9\x08N\xa8f\x9a\xd9\x9e\x0b\xae\x9ad\x92\x1e\xac\x8e0\x99\x7f\x8c\xa2\x7f\xaa\x8b\xacfh\xf6i-\xecn\x89\x97\xd24\xe5\xa5\x99\xd2\xab?g\xda=\x80AJ\xc4]\x10D\xea\xd5Bh\xf16y\xd7j\x9e\x84\x18\x19\xc1\x9caj\xd3\x9e\x8c\n\x113Z\xff\x1d\x88\xc3\xa6\xeb\xca\xe8\x12\x9c\x1a\r\x1aU\xfeT~\xf9\x10s\xe1J\xe6%\xf7n\xdeY\xb6!\x84g\xf2\x89r\x01\xe8i=\\w\x99,\xber\x0e\x1c2\xa1\xc5m\xe0\x93\xe5\r\xd0\x8a}\xc4HB\xd7/\x1f\x02\xefDiM\xda\xed\xe5b\xd6XAh\x1d\xaaD\x17\xaf Z \x9a\xf8\x95@\x90\xe0\xef\x97\xad\xbe\x81uW\xcc\x97k\xb7d \xc6"\x1a\xc3\xa0\x1a\xf61\x7ff\xfa(|7\x03\x055Q\xfb\x07\x1d8\x8a\xba\x04\xea\x94\x9b\xcc\x86\xa0\xf8\x9f\x08d\x01\xb9\xcb=X4P\xcfU\xd5\x1a\xb7\x86\xa1Hp\x8c\x0e\x0f8\xf9*\x0c\x85Q\xd0\xc9\\d|\x82\xeb\xcdnb\x07~\x8c\xc1]\xe8\x944\xb1\xadl#}\x11\x9e\x8f\xab|\\\xd1\xce\xdaY\xd2t\x1d\xaa\xb6\x16\xfe.S+\xee\xf1\xb2e\xbf*x2\xa3t\x84\xe6,\x93|\xfb\xa1\x88S\xd9\t2"\x87\xc0\xd8\xa9\xeb\x14>\xcbM\xdeT\xd0&Y\xc7\x82\xa2\xef\xc5Rz\xac\x97\xe7\xc1gM\xf4\x0b^\xdb"\xddt\xd9\x11\xab\xaa\xdfc\x9b\xac\x8c,y\xda`\xc5\xba\xca3\xddcjX{\x1a\x86\xea]\x9e\xd2,\x96\x9a\x85 \xa8*Z|Q\xac$;\xec\xe1J\x83x\xfe\x11\xcdECN\x81\x11\xee+\xde\x82\x96\x83\xb9\x80a\'Z#v\xfe\x1a#\x8f\x02J\xab9G\xb1Cn"\x1d\xb2\xfb2\x89\xb2\xddu3\x7f\x83\x85h\xda8\xa3\x89\xdf\xa88K\x84+\x12\xe5\xeb\x9f\x08g(\x89\xd4\x16\xc3=\xf5\x92\xb8\xeeTpt\xb7\xa8\x82\x06\xa6\xfd\x10\xef"YY\x94P*\xb8\x87\x15\x1d{\x07\xc1z\xfc\xceN\xfbwPJ`\xad\x0c_\x16~5\xc5^\xab6\xc2\xc1Xx3\xc7\x13\xf3M\xe9\xae\x9f\r\x19\xd1\xfa\xa7xB\x14\xab\xfbb\xbc\x89[\x9d\xd4d\x19\xcf\xc6;\x16\xc0-\x14\x8eT>K\xa9\x8d\xcc\x8a\xbcf\x16\xdabp\xd08K\xdd\xc8\xa3\xff;Z\xa4k\x99\xcd2\x87\x1e \xcfD:\x1dh\x94O\xf7m\xc1C\xea\xd3\xce.L\x81*\x932\xa2\xb1\x1f\xc5b\x96\xff\xe4\xaf5rx\xb9q\xe6\x8dR\xe8\xe9{\xa5R\x01\xf0\xb161\x17P\xcd\xb3\xfca\xde#\xb5\x97\x11\x9d*\xcc\x8f1\xe9\x90\xbam\x976u\xc1\xfc\xaam\x1b\x14f\xf3\x87Q\xdc\x9d\xa8R4\x0fE\x16\x7fc\xb0tY\x12\x9c\xc3\x92\xd4\xcaW"\x83\xb0\xedv\x1d\xaa@qo\x87B\xda\x87!\x08\xea[\x1b\xf1\xc8f\xc7Vg1\xce\xc1Z\xd8+\xbfb5iF[\x04J\xb3\xd7\xefrw\x1f\xec\x9e\xccK\xe1>\\\x9e_\x03`J\x18\x93\xca\xc2!2J\xca^m3\xb8\xf7\x07n\xc6~m\xaa\xa4\xb0\xc6\xbb\x1a\xe7h\xc6\xa9P7\xf9\x17\xeb\xe6[\x04\xed\x95\xd4\xe3\xcdA{\xd7%\xaf6\x85k\x95\xfds\xbe]}\xb2\xc3bf\xf5\xec\xa4\n\t\xe0\xbd\xff\xa6*\x92\x08\xd5?\xed\x137w\x8c\xe3\xe5n\x87\x16\xa3\xccN\x1cd\x9f\x16h\x1b\xf4L\xd5m\xf7H\xcf\xe6\xa3\xb6\xd1\xe3i{+@\x88\x94\xc4.g\xbaJ\x14su\x1c\xc0\xe40\x8f\x1f\xa5\x82\xd9\xcc04&\xb2\xcb@U\xa2h\t\xc8\x86\xb9>\x18\xb4\xc9!\xc5\x9a<\x8b\x1b3>\x18\x02\xcbo\xbf\xc7\xebe\xc1#\xcb\xb4\xb5\xa49\x84~dK\xb8\xe4\x91\xfd\xe2<\xb3\xd1\xb1\x12\xa4\xc5,\x9a\xb6\x93\x0b^\xd4\xef\xa4J\x1b_\x95\xae"\x02\x90\x9fN\x9f\xfd&\x96\n\xc8\xba\x9b\x07\xc1M\xdf\x12\xa6v\x02\x94\xeeV\x7f\xfc\xa1%M\x9dO\xd3>\xf1\xf0\xd0W\x0b\xef\xf1\xbeT\xd8+[\x95T\x80\xb9\x9dy\x82}A\xdb\xc3\xe9\xf9\x0ef\xa5I\xf8\xeb\xdcUE\x12WVs\x16R\x8a_U\x96tp(\xb7?\xfb\xec\x97\xabS\x19Q\x99\xc4\x98\xd5yK\xc2+Js\xfb\x9b\x94=]K9$|\x0c\xba\xce\x9e\xf5\x13<~\x93\x0f"\xb2:k>\x16\x04\x90tM$*\x158\x1f\x94\x86]\xceLbwx'
#
# Signature in hex: ...
#
# Signature in base64: ...
#
#
# Signature Size: 1273 bytes
#
# ✅ Success! Signature is valid and authentic.
