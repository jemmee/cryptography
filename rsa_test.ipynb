# %%
from cryptography.hazmat.primitives import hashes, serialization
from cryptography.hazmat.primitives.asymmetric import rsa, padding
import base64

# ============================
# Generate RSA key pair
# ============================
def generate_rsa_keys():
    private_key = rsa.generate_private_key(
        public_exponent=65537,    # Standard and secure
        key_size=15360
    )
    public_key = private_key.public_key()

    # Serialize keys to PEM format (for saving or sharing)
    private_pem = private_key.private_bytes(
        encoding=serialization.Encoding.PEM,
        format=serialization.PrivateFormat.PKCS8,
        encryption_algorithm=serialization.NoEncryption()
    )
    public_pem = public_key.public_bytes(
        encoding=serialization.Encoding.PEM,
        format=serialization.PublicFormat.SubjectPublicKeyInfo
    )

    return private_key, public_key, private_pem.decode(), public_pem.decode()

# ============================
# Encrypt with public key
# ============================
def encrypt_rsa(message: str, public_key) -> str:
    ciphertext = public_key.encrypt(
        message.encode('utf-8'),
        padding.OAEP(
            mgf=padding.MGF1(algorithm=hashes.SHA256()),
            algorithm=hashes.SHA256(),
            label=None
        )
    )
    return base64.b64encode(ciphertext).decode('utf-8')

# ============================
# Decrypt with private key
# ============================
def decrypt_rsa(encrypted_b64: str, private_key) -> str:
    ciphertext = base64.b64decode(encrypted_b64)
    plaintext = private_key.decrypt(
        ciphertext,
        padding.OAEP(
            mgf=padding.MGF1(algorithm=hashes.SHA256()),
            algorithm=hashes.SHA256(),
            label=None
        )
    )
    return plaintext.decode('utf-8')

# ============================
# Demo
# ============================
if __name__ == "__main__":
    print("Generating RSA key pair...\n")
    private_key, public_key, private_pem, public_pem = generate_rsa_keys()
    
    print(f"RSA Modulus Strength: {public_key.key_size} bits\n")

    message = "Hello from RSA! This message is confidential. 🔒"

    print(f"Original message: {message}\n")

    # Encrypt with public key
    encrypted = encrypt_rsa(message, public_key)
    print("Encrypted (Base64):")
    print(encrypted)
    print()

    # Decrypt with private key
    decrypted = decrypt_rsa(encrypted, private_key)
    print(f"Decrypted message: {decrypted}\n")

    # Verify
    assert decrypted == message
    print("Success! RSA encryption and decryption worked perfectly.")

    # Optional: Show public key (safe to share)
    print("\nPublic Key (can be shared openly):")
    print(public_pem)
# Out:
# Generating RSA key pair...
#
# RSA Modulus Strength: 15360 bits
#
# Original message: Hello from RSA! This message is confidential. 🔒
#
# Encrypted (Base64):
# ...
#
# Decrypted message: Hello from RSA! This message is confidential. 🔒
#
# Success! RSA encryption and decryption worked perfectly.
#
# Public Key (can be shared openly):
# -----BEGIN PUBLIC KEY-----
# MIIHojANBgkqhkiG9w0BAQEFAAOCB48AMIIHigKCB4EAs+3bFUuXWkCYMHHPT+mm
# Gt507HzytMXVKOeYbaOMJQ+3OWyo8YivEA4gtDuNDpdqo6ksD29bEC+37Yn5/bwj
# Rnvulk3Q/hcx6GA7bYcClHNmgYaNcwO2u8pyIDes9YmtWp+9hA9OXWsJ7cE1Gztt
# CAs2kTUPjkli+QHTkNTbrXPOmKJU9BHWdLHDPJFXgPESDCD5JRQbDTyizWGQ1/ft
# NGVYOB/N5ITh/F5XTxitYjAsOVlnBuigobzr/8HC4wmsCT2llQ6QimnydyZWb6HF
# lbiG9Zj7xOfYDh0g1VJxGyDz873LTiufwiHAhzVntg8NtVG7ZNWqd5EMBEM7syzg
# TX7FemtJ6g/x9TllXf+cztL5DNdNZwfHF7+QcoTf66XwzhuBnO29BnxcIcZciFwN
# 86iC+9BsqGBKl/eYp2VY73lHMLpzqotd0E8NSit0eLh6RSr6M/b3Xs1yKBBcUPuh
# gDIHG65Y2I5AwDRseAPSe68ahMRd+nY+opu/a9CMLbIctWoXDYmFpC6KXEczl6+N
# 0fvLvCx2xExN1yCksllOe2uc6sQV4g8JKraQD3UjlOlPVTBy6k8TbFdJH7nhNy75
# badogI1ncNM+6pFbHYmvSC2ljwNKp5cF6AFxYHW8GdqGG4OH5/e6bmoQtt43J7K6
# FwDz8xI8r4FHSWughc31xuot41E9YPp5jqHlyTIncbZuTKMI2mo/HU1f6wYxSGNl
# 0RV0n+Xn+T+eWYtQ+S5njp/LuBU22vQ6/ne3T9RlPu6AL9eE9nEbctMYtlY22ZcE
# FW7/PG5dC9wZF5M9W6YvXFIDIbuCAztgxzJNNCxxDV//k8LDcFpVUTu63Irad62S
# dr+wjJgTeiFJ5LcHF2lyFQ6iW6SgjhWWh3TMXF38T48XNh5JP7ZzM8Xj/r4WrViz
# 7VNB7M2m+SMraFCEiqSlB5WA0vyDSucrl2pAeRqQCul2GJIyyq/QptldlmijNHCu
# nidhRvj/9YPpN0RzGIJ5iO2b2sFZKoN31Vhi60wLnJwOGL5W7vHUFuN23ZhQWhK/
# zcy0YCGktTcMjtXT2wg7k5GW8D3Xb0kpQPNfRYlwf2Re3Y2dQaysoEHROxIg/Mn1
# JZH2TfX4a1DdrZ2KFNUpylRF8a5Hi6TmyLTSDVms0mSfAj3hjtSf5Y9RB+P+R80O
# u61kcnoVDlqj0XRE3uyLppTBOSEQJsgRFFrGFjfv3I6pdbskcNp1D+GVcQ9dra+2
# 8IHRB74Bmc4tcGuoTCqYnGA/G6Bc430mpGXfMq7Irhgys3Q7t/zXtxj2lNcs9WGO
# GUKzR+Ewor5YKm/ymxdVpPSzAHkhGvCuSDyYUPCQ9aIzRc77hgWWPl3w00RamaG8
# 6o3WMSOFirYbp/UmwC0Sn6OmFgqGpINFNbiDBZbzFncYueKA2weGDibSQ2z7syvO
# l6HqX2we9RxlDVTIkoEPl3yW3ASL8SB8JZ3ZzCA116NsktPwQEaPtcrYcLnjYkYF
# lWPF/tVfTiYwnu/FYbmeiAHu7v2TWgsG4w6qx4UIQhBpXfTjU4Ko4JeiUpKpwstx
# PuPOmCb/qjLnH39xutmzMI6GatSseAn8Xeyc6WuD+Iby1a3IvBhgd7FJ520gXH6e
# l8frBLikM7UrFc9vnjhlisDrgzGdrgx06p/k6ZBcstupOfoObIUCJRZCQpeNE65Z
# TMvNnW0E2I05H/fzT0DkBH36WLook1x+/XKxE0s9Xlkc5hLoPTjCq1WmifqmRuLX
# oM3luGnoc/uqNC6CStnXfre661C3dQUqENmcHGLkXK14sHbJTHZOAyo/xjpqR5j2
# sY00wnUebtHFc5/X4IW4luoqAhjfpi6eXXXhsEoCN0FhTuVEe6Vg8J+zOwwQ+L6c
# JVjRmSrjr6jg/jWJW1yH9OatNii8wLUzX9J98qLf6OxyJN2+z2MmMhs43HzDUpV6
# EkFUq5EOvJN7nWeTcRTp/l2w8vd//A3UzGYeRVILLUsKyGLDRUd5Pjz+eEAgir71
# oUkEVNIdbVJGFBr3WWRCAAXfk5hOwPNzwbEaLB+6i1IZXPIG0N+WPUHPmVNC1NKh
# qY1SR6xKhsqg+13eTKhlKukdTvaGUPwYK71xA3/mK7mchrYehIN/k4SLmJEQiuxJ
# Y2p3XKMDjL22z/K/8QEtd5Mcl+LmtdTpmlSUohc9PnicCdlET42rvQmC93YgyO9A
# C2gfVQYrfWoc6OI7vht9ozGM0Vsw5oQBCVqGgdf3w+fiatFJBxtWC+GNh6Eb9HuB
# 5NiApB8bR0zEBAHOEN7IDFrqVPQCTzlT5SqUZ48of4qRZ6ugJnWqKV5KhX37ukf3
# WERz4zpgKdphCreFIL90AEsKkmx1HR0ng8H+IdisavggRIL6JcJYmvPiMZENKpwp
# oilvZXyS4NtwO8WiOHXAAvF+1pm2HnVD1I8zqYB7XMYM39pJ/Bg+4YxX3UgsMX6Q
# QBV2fFWwC90q4V8BrAm9h38WDndxINZJNNoWCEIslqK6vMNPG39g1UBRzMw7jqie
# kiusnGKJCIyKKvwtIi7ydnva/gLPg4dKBsCTOZ/OGFzfAgMBAAE=
# -----END PUBLIC KEY-----
