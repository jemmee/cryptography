# %%
# !pip install pycryptodome
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.5/2.5 MB 16.9 MB/s  0:00:00
# ...

# %%
from Crypto.Hash import keccak

def demo_keccak():
    print("--- Raw Keccak-256 Demo ---")
    
    user_input = input("Enter text to hash with Keccak: ")
    data = user_input.encode('utf-8')
    
    # Initialize Keccak-256 (The Ethereum Standard)
    keccak_hash = keccak.new(digest_bits=256)
    keccak_hash.update(data)
    
    result = keccak_hash.hexdigest()
    
    print(f"\nInput:  {user_input}")
    print(f"Keccak-256: {result}")

if __name__ == "__main__":
    demo_keccak()
# Out:
# --- Raw Keccak-256 Demo ---
# Enter text to hash with Keccak:  In the beginning God created the heavens and the earth
# Input:  In the beginning God created the heavens and the earth
# Keccak-256: 550a980d45c3305e72a4faf49ea1a69470bee62d6731483ad01d76e7ed469571
