# %%
# !pip install cryptography

# %%
# !openssl req -x509 -newkey rsa:2048 -keyout private_key.pem -out certificate.pem -days 365 -nodes

# %%
from cryptography import x509
from cryptography.hazmat.primitives import hashes, serialization
from cryptography.hazmat.primitives.serialization import pkcs7

# 1. LOAD YOUR CERTIFICATE AND PRIVATE KEY
# (Assuming you have 'certificate.pem' and 'private_key.pem')
with open("certificate.pem", "rb") as f:
    cert = x509.load_pem_x509_certificate(f.read())

with open("private_key.pem", "rb") as f:
    private_key = serialization.load_pem_private_key(f.read(), password=None)

# 2. DATA TO SIGN
data_to_sign = b"I have set my rainbow in the clouds, and it will be the sign of the covenant between me and the earth."

# 3. CREATE THE PKCS7 SIGNATURE
# We are creating a "detached" signature in S/MIME format
pkcs7_signed_data = builder.sign(serialization.Encoding.PEM, options)

print("--- PKCS7 SIGNED MESSAGE ---")
print(pkcs7_signed_data.decode())
# Out:
# --- PKCS7 SIGNED MESSAGE ---
# -----BEGIN PKCS7-----
# MIIJJQYJKoZIhvcNAQcCoIIJFjCCCRICAQExDzANBglghkgBZQMEAgEFADALBgkq
# hkiG9w0BBwGgggWjMIIFnzCCA4egAwIBAgIUEVbLrywG7CMZESrl2A2umUU4Xpww
# DQYJKoZIhvcNAQELBQAwXzELMAkGA1UEBhMCVVMxEzARBgNVBAgMCkNhbGlmb3Ju
# aWExFjAUBgNVBAcMDU1vdW50YWluIFZpZXcxDTALBgNVBAoMBE9DSlkxFDASBgNV
# BAMMC3Jhc3BiZXJyeXBpMB4XDTI1MDgyODIzMDkxNloXDTM1MDgyNjIzMDkxNlow
# XzELMAkGA1UEBhMCVVMxEzARBgNVBAgMCkNhbGlmb3JuaWExFjAUBgNVBAcMDU1v
# dW50YWluIFZpZXcxDTALBgNVBAoMBE9DSlkxFDASBgNVBAMMC3Jhc3BiZXJyeXBp
# MIICIjANBgkqhkiG9w0BAQEFAAOCAg8AMIICCgKCAgEArWypT1MWg9mWNck65cb4
# TEzp8dVNYgGTCoMiUzz7DNpbjNMeycAS4PKUWHeERAhXyr5TCkesNGT2fp5tbeSS
# JeJ9aQqculQ3rAkwx8SmjwMVxSMk4KqjYVjoWI34862ZQ6D33/Cz4CrBhR34ek1F
# +flCExWDl+01jmCVbxj+ayficI+7geN0V5fsduALtHsgRX3lmB51wzn7UzdxFNfW
# PONLN6a6Brm8VzUWNQHC5fM4HwR14oQtyuKlJzOcKSQQip7OmNPBYJmyEinU81EO
# Xy1hNR61+UB9fZvdemR0grZu3xZbe7RDcfjjyqUnHeBDTnq0qZ800Yzdd4dhWL02
# F5xFqxtQ8CoDQrHozJvHtBy/CxFjuRlPse2q62TepBWXeQB6OXRX5RP5upZlJgtb
# ...
