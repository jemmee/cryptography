# %%
# !pip install pykmip
# Out:
# Requirement already satisfied: pykmip in /opt/anaconda3/lib/python3.13/site-packages (0.10.0)
# Requirement already satisfied: cryptography in /opt/anaconda3/lib/python3.13/site-packages (from pykmip) (44.0.1)
# Requirement already satisfied: enum-compat in /opt/anaconda3/lib/python3.13/site-packages (from pykmip) (0.0.3)
# Requirement already satisfied: requests in /opt/anaconda3/lib/python3.13/site-packages (from pykmip) (2.32.5)
# Requirement already satisfied: six in /opt/anaconda3/lib/python3.13/site-packages (from pykmip) (1.17.0)
# Requirement already satisfied: sqlalchemy in /opt/anaconda3/lib/python3.13/site-packages (from pykmip) (2.0.39)
# Requirement already satisfied: cffi>=1.12 in /opt/anaconda3/lib/python3.13/site-packages (from cryptography->pykmip) (1.17.1)
# Requirement already satisfied: pycparser in /opt/anaconda3/lib/python3.13/site-packages (from cffi>=1.12->cryptography->pykmip) (2.21)
# Requirement already satisfied: charset_normalizer<4,>=2 in /opt/anaconda3/lib/python3.13/site-packages (from requests->pykmip) (3.4.3)
# Requirement already satisfied: idna<4,>=2.5 in /opt/anaconda3/lib/python3.13/site-packages (from requests->pykmip) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /opt/anaconda3/lib/python3.13/site-packages (from requests->pykmip) (2.5.0)
# Requirement already satisfied: certifi>=2017.4.17 in /opt/anaconda3/lib/python3.13/site-packages (from requests->pykmip) (2025.8.3)
# Requirement already satisfied: typing-extensions>=4.6.0 in /opt/anaconda3/lib/python3.13/site-packages (from sqlalchemy->pykmip) (4.15.0)

# %%
# docker run -d --security-opt seccomp=unconfined --cap-add=NET_ADMIN --rm -p 5696:5696 --name kmip altmannmarcelo/kmip:latest
#
# mkdir /tmp/certs
# docker cp kmip:/opt/certs/root_certificate.pem /tmp/certs/
# docker cp kmip:/opt/certs/client_key_jane_doe.pem /tmp/certs/
# docker cp kmip:/opt/certs/client_certificate_jane_doe.pem /tmp/certs/
#
# python3.11 -m venv python311
# source python311/bin/activate
# pip install jupyter ipykernel
# python -m ipykernel install --user --name=python311 --display-name "Python 3.11"
#
# sudo date 120100002025

from kmip.pie import client
from kmip.pie import objects
from kmip import enums
import binascii
import os
from kmip.core import enums

c = client.ProxyKmipClient(hostname='localhost', port=5696, ca='/tmp/certs/root_certificate.pem', cert='/tmp/certs/client_certificate_jane_doe.pem', key='/tmp/certs/client_key_jane_doe.pem')

with c:
    # 2. Create a Symmetric Key
    # We define the algorithm (AES), length (128), and what it's allowed to do
    key_id = c.create(
        enums.CryptographicAlgorithm.AES,
        128,
        cryptographic_usage_mask=[
            enums.CryptographicUsageMask.ENCRYPT,
            enums.CryptographicUsageMask.DECRYPT
        ]
    )
    
    # Activate the key so the server allows its use
    c.activate(key_id)
    print(f"Created and Activated Key ID: {key_id}")

    # 3. Encryption
    message = b"A gossip betrays a confidence, but a trustworthy person keeps a secret."
    
    # We specify the key ID, algorithm, and cipher mode
    cipher_text, iv = c.encrypt(
        message,
        uid=key_id,
        cryptographic_parameters={
            'cryptographic_algorithm': enums.CryptographicAlgorithm.AES,
            'block_cipher_mode': enums.BlockCipherMode.CBC,
            'padding_method': enums.PaddingMethod.ANSI_X923
        }
    )
    print(f"Cipher Text: {cipher_text.hex()}")

    # 4. Decryption
    # You must provide the same parameters and the IV received during encryption
    decrypted_data = c.decrypt(
        cipher_text,
        uid=key_id,
        cryptographic_parameters={
            'cryptographic_algorithm': enums.CryptographicAlgorithm.AES,
            'block_cipher_mode': enums.BlockCipherMode.CBC,
            'padding_method': enums.PaddingMethod.ANSI_X923
        },
        iv_counter_nonce=iv
    )

    print(f"Decrypted Result: {decrypted_data.decode('utf-8')}")
# Out:
# Config file ['/Users/jemmeeyung/.pykmip/pykmip.conf', '/etc/pykmip/pykmip.conf', '/Users/jemmeeyung/projects/cryptography/python311/lib/python3.11/site-packages/kmip/pykmip.conf', '/Users/jemmeeyung/projects/cryptography/python311/lib/python3.11/site-packages/kmip/kmipconfig.ini'] not found
# Created and Activated Key ID: 1
# Cipher Text: 1d394a3315f00e1ce1b738fb58796239789c90b6645419367b5c451d3de33ad7f057b6f77aceeca77e52a891c53f7cc62777c30af9418ae547b40d1eaf71e6fd3ce5f65300873b21b49e8fcd4e640d32
# Decrypted Result: A gossip betrays a confidence, but a trustworthy person keeps a secret.
