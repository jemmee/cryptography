# %%
# !pip install signxml
# Out:
# Collecting signxml
#   Downloading signxml-4.2.0-py3-none-any.whl.metadata (16 kB)
# Requirement already satisfied: certifi>=2023.11.17 in /opt/anaconda3/lib/python3.13/site-packages (from signxml) (2025.8.3)
# Requirement already satisfied: cryptography>=43 in /opt/anaconda3/lib/python3.13/site-packages (from signxml) (44.0.1)
# Requirement already satisfied: lxml<7,>=5.2.1 in /opt/anaconda3/lib/python3.13/site-packages (from signxml) (5.3.0)
# Requirement already satisfied: cffi>=1.12 in /opt/anaconda3/lib/python3.13/site-packages (from cryptography>=43->signxml) (1.17.1)
# Requirement already satisfied: pycparser in /opt/anaconda3/lib/python3.13/site-packages (from cffi>=1.12->cryptography>=43->signxml) (2.21)
# Downloading signxml-4.2.0-py3-none-any.whl (59 kB)
# Installing collected packages: signxml
# Successfully installed signxml-4.2.0

# %%
from lxml import etree
from signxml import XMLSigner, XMLVerifier

# 1. Load your key and certificate
with open("private_key.pem", "rb") as f:
    key = f.read()
with open("certificate.pem", "rb") as f:
    cert = f.read()

# 2. Create a sample XML document
root = etree.fromstring("<Message><Body>Never again will the waters become a flood to destroy all life.</Body></Message>")

# 3. Sign the XML
# Enveloped signature means the <Signature> block is placed inside the XML
signed_root = XMLSigner().sign(root, key=key, cert=cert)

# 4. Output the signed XML
signed_xml = etree.tostring(signed_root, pretty_print=True).decode()
print("--- SIGNED XML ---")
print(signed_xml)
# Out:
# --- SIGNED XML ---
# <Message>
#   <Body>Never again will the waters become a flood to destroy all life.</Body>
#   <ds:Signature xmlns:ds="http://www.w3.org/2000/09/xmldsig#">
#     <ds:SignedInfo>
#       <ds:CanonicalizationMethod Algorithm="http://www.w3.org/2006/12/xml-c14n11"/>
#       <ds:SignatureMethod Algorithm="http://www.w3.org/2001/04/xmldsig-more#rsa-sha256"/>
#       <ds:Reference URI="">
#         <ds:Transforms>
#           <ds:Transform Algorithm="http://www.w3.org/2000/09/xmldsig#enveloped-signature"/>
#           <ds:Transform Algorithm="http://www.w3.org/2006/12/xml-c14n11"/>
#         </ds:Transforms>
#         <ds:DigestMethod Algorithm="http://www.w3.org/2001/04/xmlenc#sha256"/>
#         <ds:DigestValue>bonhjxWpCdpqQhvtVplo3GhAFAV9Sz1tqZm7rwKbdJE=</ds:DigestValue>
#       </ds:Reference>
#     </ds:SignedInfo>
#     <ds:SignatureValue></ds:SignatureValue>
#     <ds:KeyInfo>
#       <ds:X509Data>
#         <ds:X509Certificate>MIIDwTCCAqmgAwIBAgIURqqY3JSzhjuz6Hmq8IvupaGlCWwwDQYJKoZIhvcNAQEL
# BQAwcDELMAkGA1UEBhMCVVMxEzARBgNVBAgMCkNhbGlmb3JuaWExFjAUBgNVBAcM
# DU1vdW50YWluIFZpZXcxITAfBgNVBAoMGEludGVybmV0IFdpZGdpdHMgUHR5IEx0
# ZDERMA8GA1UEAwwISm9obiBEb2UwHhcNMjUxMjMwMDI0MjQ0WhcNMjYxMjMwMDI0
# MjQ0WjBwMQswCQYDVQQGEwJVUzETMBEGA1UECAwKQ2FsaWZvcm5pYTEWMBQGA1UE
# BwwNTW91bnRhaW4gVmlldzEhMB8GA1UECgwYSW50ZXJuZXQgV2lkZ2l0cyBQdHkg
# THRkMREwDwYDVQQDDAhKb2huIERvZTCCASIwDQYJKoZIhvcNAQEBBQADggEPADCC
# AQoCggEBALHEyO7m9ewasETdYPdKe6S/w0AaMlVF0JIXMJY+nWpW6gZrFFttQW/u
# bEnOqSw6tOyKKg4LNFAVAHmruXbpKb4mJ2QbBeUuihQgQyFyB4O/yT+ujnuNG2D0
# FjNKtdXqyBZuFZeT0eidxYikz2nIP2uphfngRvCrfufQigbmXqYXIm5nlgykgWyo
# w3u9G+P1r547T6OAGIVLRxE3zKAA/icefeZGWJHINbIgsfgXy6lE9fwqvQdWgfQ/
# IuoO6AU8sk6styNb8e0AAr3IpBE1in2/oMFR7MF0tJYAcMZoVbbyvGRHD4kSRBB5
# UHsEVPttatNJz3HuvvwxAWSw7EyagZECAwEAAaNTMFEwHQYDVR0OBBYEFKWFjLRE
# yn+tY5E1UOTkN0qkkTMNMB8GA1UdIwQYMBaAFKWFjLREyn+tY5E1UOTkN0qkkTMN
# MA8GA1UdEwEB/wQFMAMBAf8wDQYJKoZIhvcNAQELBQADggEBAIdMDU6g8IfpO6D5
# 5pIGJAAAxj5d4ypdD9BXtdO47J+lnMOHkOyBzZwIQXw7N3zltPFyPkThBEJPqq9m
# cCn7kXbOz3nqPnV8xvSskcFRh2K8uLV6SMIng3DP+Uhut5wC2bBlXjuITAi05J7c
# QLSiOiqYW1++/sBN/yUs8RzdpeknBuzo6xB/sdH+cDfRKlXcaW2jMa3+tKkb6l3E
# jBlwM7dZmcD3LP/SsOAn8BcJEa/YC56PalGpbWfsII0P/GqZq3rMcwUkWAhk4M7c
# gkI4KQiOsCpdZ3sIQ4njX4cKrhac5JLjcONWN8qach/xbrh583ma1qUxwe/G5Sa/
# 4N6pxaI=
# </ds:X509Certificate>
#       </ds:X509Data>
#     </ds:KeyInfo>
#   </ds:Signature>
# </Message>

# %%
# Use the signed_root from the previous step
try:
    # We provide the certificate to verify the signature
    verified_data = XMLVerifier().verify(signed_root, x509_cert=cert)
    print("\nVerification Successful!")
    print("Signed data verified:", etree.tostring(verified_data.signed_xml).decode())
except Exception as e:
    print(f"\nVerification Failed: {e}")
# Out:
# Verification Successful!
# Signed data verified: <Message><Body>Never again will the waters become a flood to destroy all life.</Body></Message>
